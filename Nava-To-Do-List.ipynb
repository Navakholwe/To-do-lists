# %%
tdl = []

def add_task(task):
    tdl.append(task)
    print(f"Task '{task}' added to the list.")
    
def complete_task(task):
    if task in tdl:
        tdl.remove(task)
        print(f"Task '{task}' marked as complete!")
    else:
        print("Task not found!")

def list_tasks():
    if not tdl:
        print("To-do list is empty!")
    else:
        for i, task in enumerate(tdl, 1):
            print(f"{i}. {task}")

def remove_task(task):
    if task in tdl:
        tdl.remove(task)
        print(f"Task '{task}' removed from the list.")
    else:
        print("Task not found.")

def main():
    print("Welcome to Your To-Do List App!")
    
    while True:
        print("1. Add a task")
        print("2. Mark a task as complete")
        print("3. Display all tasks")
        print("4. Remove a task")
        print("5. Quit")
        
        choice = input("Enter your choice: ")
        
        if choice == '1':
            task = input("Enter task to add: ")
            add_task(task)
        elif choice == '2':
            task = input("Enter task to mark as complete: ")
            complete_task(task)
        elif choice == '3':
            list_tasks()
        elif choice == '4':
            task = input("Enter task to remove: ")
            remove_task(task)
        elif choice == '5':
            print("Quitting...")
            break
        else:
            print("Invalid choice. Please enter a valid option.")

if __name__ == "__main__":
    main()
# Out:
# Welcome to Your To-Do List App!
# 1. Add a task
# 2. Mark a task as complete
# 3. Display all tasks
# 4. Remove a task
# 5. Quit
# Enter your choice: 1
# Enter task to add: Run
# Task 'Run' added to the list.
# 1. Add a task
# 2. Mark a task as complete
# 3. Display all tasks
# 4. Remove a task
# 5. Quit
# Enter your choice: 1
# Enter task to add: Shop groceries
# Task 'Shop groceries' added to the list.
# 1. Add a task
# 2. Mark a task as complete
# 3. Display all tasks
# 4. Remove a task
# 5. Quit
# Enter your choice: 1
# Enter task to add: Attend meeting
# Task 'Attend meeting' added to the list.
# 1. Add a task
# 2. Mark a task as complete
# 3. Display all tasks
# 4. Remove a task
# 5. Quit
# Enter your choice: 1
# Enter task to add: Clone Ealy
# Task 'Clone Ealy' added to the list.
# 1. Add a task
# 2. Mark a task as complete
# 3. Display all tasks
# 4. Remove a task
# 5. Quit
# Enter your choice: 1
# Enter task to add: Take a nap
# Task 'Take a nap' added to the list.
# 1. Add a task
# 2. Mark a task as complete
# 3. Display all tasks
# 4. Remove a task
# 5. Quit
# Enter your choice: 2
# Enter task to mark as complete: take a nap
# Task not found!
# 1. Add a task
# 2. Mark a task as complete
# 3. Display all tasks
# 4. Remove a task
# 5. Quit
# Enter your choice: 2
# Enter task to mark as complete: Take a nap
# Task 'Take a nap' marked as complete!
# 1. Add a task
# 2. Mark a task as complete
# 3. Display all tasks
# 4. Remove a task
# 5. Quit
# Enter your choice: 3
# 1. Run
# 2. Shop groceries
# 3. Attend meeting
# 4. Clone Ealy
# 1. Add a task
# 2. Mark a task as complete
# 3. Display all tasks
# 4. Remove a task
# 5. Quit
# Enter your choice: 4
# Enter task to remove: Clone Ealy
# Task 'Clone Ealy' removed from the list.
# 1. Add a task
# 2. Mark a task as complete
# 3. Display all tasks
# 4. Remove a task
# 5. Quit
# Enter your choice: 3
# 1. Run
# 2. Shop groceries
# 3. Attend meeting
# 1. Add a task
# 2. Mark a task as complete
# 3. Display all tasks
# 4. Remove a task
# 5. Quit
# Enter your choice: 5
# Quitting...
